# %%
# !pip install nltk scikit-learn pandas

# %%
import nltk
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
data = {
    'Question': [
        "Hi"
        "How much is the admission fee?",
        "How can I apply for a hostel?",
        "When will exams start?",
        "What is the library timing?",
        "Who is the Dean of the university?",
        "How do I pay my semester fees?",
        "What are the hostel rules?",
        "Is there Wi-Fi available in hostels?",
        "What is the dress code for students?",
        "How can I get my ID card?",
        "What documents are required for admission?",
        "What is the last date for admission?",
        "How can I check my attendance?",
        "How can I get my marksheet?",
        "How to apply for a scholarship?",
        "What scholarships are available?",
        "How do I reset my student portal password?",
        "How can I contact the examination cell?",
        "When will the next semester start?",
        "How can I download my admit card?",
        "Where can I find the academic calendar?",
        "How can I apply for a migration certificate?",
        "What are the hostel timings?",
        "Is there a curfew in the hostel?",
        "Can parents stay in the hostel?",
        "Is there a gym on campus?",
        "How can I use the gym?",
        "Are there sports facilities in the university?",
        "What is the placement rate of the university?",
        "Which companies visit for placements?",
        "Who is the placement officer?",
        "How can I register for placement drives?",
        "What is the minimum CGPA required for placement?",
        "How can I get a bonafide certificate?",
        "Where can I pay my hostel fees?",
        "Is there a fine for late fee payment?",
        "How can I apply for a duplicate ID card?",
        "What are the exam passing criteria?",
        "When will the results be declared?",
        "What is the re-evaluation process?",
        "How can I apply for re-evaluation?",
        "Is there a medical facility on campus?",
        "What is the contact number for medical emergencies?",
        "Is there a transport facility?",
        "How can I get a bus pass?",
        "What are the bus routes?",
        "Is there parking available on campus?",
        "How can I get a library membership?",
        "How many books can I issue from the library?",
        "What is the fine for late book return?",
        "Can I access e-books online?",
        "Where can I find previous year question papers?",
        "How can I contact the admin office?",
        "Is there an internship program?",
        "How can I apply for an internship?",
        "What is the duration of each semester?",
        "Is there a canteen on campus?",
        "What are the canteen timings?",
        "Can I pay fees in installments?",
        "How can international students apply?",
        "What is the university helpline email?",
        "How can I get a transfer certificate?"
    ],
    'Answer': [
        "Admission fee is ₹5000.",
        "Fill the hostel form online at hostel.university.edu.",
        "Exams will begin in December as per the academic calendar.",
        "Library is open from 8 AM to 8 PM on weekdays.",
        "The Dean of the university is Dr. R. Sharma.",
        "You can pay your semester fees through the student portal online.",
        "Hostel rules are mentioned in the student handbook. Ragging and late entry are strictly prohibited.",
        "Yes, all hostels have high-speed Wi-Fi facilities for students.",
        "Students are expected to dress decently in formal or semi-formal attire.",
        "Visit the admin office with your admission slip to collect your ID card.",
        "Documents required include mark sheets, ID proof, photos, and transfer certificate.",
        "The last date for admission is generally July 31st.",
        "You can check your attendance on the student portal under the ‘Attendance’ section.",
        "You can collect your marksheet from the examination cell after results are announced.",
        "Apply for scholarships through the scholarship portal on the university website.",
        "Merit-based and need-based scholarships are available for eligible students.",
        "Go to the student login page and click on ‘Forgot Password’ to reset it.",
        "You can email examcell@university.edu for any exam-related queries.",
        "The next semester will start in January according to the academic schedule.",
        "You can download your admit card from the student portal before exams.",
        "The academic calendar is available on the official university website.",
        "Submit a written request at the admin office for migration certificate.",
        "Hostel gates close at 9 PM for girls and 10 PM for boys.",
        "Yes, there is a curfew for safety reasons.",
        "Parents are not allowed to stay in the hostel rooms.",
        "Yes, the university gym is open to all students.",
        "Register at the sports office to use the gym facilities.",
        "Yes, there are facilities for cricket, football, badminton, and more.",
        "The university has a placement rate of over 90% every year.",
        "Top companies like TCS, Infosys, Wipro, and Deloitte visit for placements.",
        "The placement officer is Ms. Priya Verma.",
        "You can register for placement drives through the placement portal.",
        "A minimum CGPA of 6.5 is required to sit for most placement drives.",
        "Apply for a bonafide certificate through the admin portal online.",
        "Hostel fees can be paid online through the hostel payment section.",
        "A late payment fine of ₹100 per day applies after the due date.",
        "Apply at the admin office for a duplicate ID card by paying ₹200.",
        "Students must score at least 40% marks in each subject to pass.",
        "Results are declared within one month after exams.",
        "Re-evaluation can be requested within 15 days of result declaration.",
        "Fill out the re-evaluation form available on the exam portal.",
        "Yes, a 24x7 medical facility is available on campus.",
        "For emergencies, contact the campus medical center at 1800-123-456.",
        "Yes, the university provides bus transport for students and staff.",
        "Bus passes are issued at the transport office with a photo ID.",
        "Bus routes are displayed on the university transport portal.",
        "Yes, parking space is available for both two-wheelers and cars.",
        "Register at the library counter to get your library card.",
        "Students can issue up to 3 books at a time for 15 days.",
        "The fine for late book return is ₹5 per day per book.",
        "Yes, e-books and journals can be accessed via library.university.edu.",
        "Previous year papers are available in the library and student portal.",
        "Contact the admin office at admin@university.edu for general queries.",
        "Yes, internships are offered through the Training & Placement Cell.",
        "Apply for internships via the placement portal or department notice board.",
        "Each semester is approximately 6 months long.",
        "Yes, the canteen serves hygienic food at affordable prices.",
        "Canteen is open from 8 AM to 7 PM daily.",
        "Yes, fees can be paid in two installments with prior approval.",
        "International students can apply via the international admissions page.",
        "You can email helpdesk@university.edu for assistance.",
        "Apply for a transfer certificate by submitting a written request to admin."
        "Hi"
    ]
}

df = pd.DataFrame(data)

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    tokens = [t for t in tokens if t not in string.punctuation]
    tokens = [lemmatizer.lemmatize(t) for t in tokens if t not in stop_words]
    return ' '.join(tokens)

# %%
df['Processed_Q'] = df['Question'].apply(preprocess)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['Processed_Q'])

# %%
def get_answer(user_query):
    query_processed = preprocess(user_query)
    query_vec = vectorizer.transform([query_processed])
    similarity = cosine_similarity(query_vec, X)
    idx = similarity.argmax()
    best_score = similarity[0][idx]

    if best_score < 0.2:
        return "Sorry, I couldn't understand your question. Please try again."
    else:
        return df['Answer'][idx]

# %%
print("🎓 Welcome to the University FAQ Chatbot! Type 'exit' to stop.\n")
while True:
    user_input = input("You: ")
    if user_input.lower() in ['exit', 'quit']:
        print("Chatbot: Goodbye! 👋")
        break
    response = get_answer(user_input)
    print("Chatbot:", response)
# Out:
# 🎓 Welcome to the University FAQ Chatbot! Type 'exit' to stop.
#
# You: hi
# Chatbot: Sorry, I couldn't understand your question. Please try again.
